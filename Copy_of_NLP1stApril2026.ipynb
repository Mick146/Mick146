# %% [markdown]
# <a href="https://colab.research.google.com/github/Mick146/Mick146/blob/main/Copy_of_NLP1stApril2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Tokeinzation**
# It means breaking a large piece of text into smaller piece called tokens
#
# **Types of Tokenization**
# * Sentence Tokenization - splits the text into sentences
# * Word Tokenization
# * Character Tokenization
# * SubWord Tokenization

# %% [markdown]
# **Sentence Tokenization**

# %%
import nltk

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# .? !
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
text = "Hello! How are you doing? I am Learning NLP. It's really amazing. Dr. Aryan went to New York"
sentences = sent_tokenize(text)
print(sentences)
# Out:
# ['Hello!', 'How are you doing?', 'I am Learning NLP.', "It's really amazing.", 'Dr. Aryan went to New York']

# %% [markdown]
# **SpaCy**

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp(text)
for i, sent in enumerate(doc.sents,1):
  print(f'Sentence {i}: {sent.text}')
# Out:
# Sentence 1: Hello!
# Sentence 2: How are you doing?
# Sentence 3: I am Learning NLP.
# Sentence 4: It's really amazing.
# Sentence 5: Dr. Aryan went to New York

# %% [markdown]
# **Word Tokenization**

# %%
text = "Hello! How are you doing? I am Learning NLP. It's really amazing."
words = word_tokenize(text)
print(words)
# Out:
# ['Hello', '!', 'How', 'are', 'you', 'doing', '?', 'I', 'am', 'Learning', 'NLP', '.', 'It', "'s", 'really', 'amazing', '.']

# %%
doc = nlp(text)
words_spacy = [token.text for token in doc]
words_spacy
# Out:
# ['Hello',
#  '!',
#  'How',
#  'are',
#  'you',
#  'doing',
#  '?',
#  'I',
#  'am',
#  'Learning',
#  'NLP',
#  '.',
#  'It',
#  "'s",
#  'really',
#  'amazing',
#  '.']

# %% [markdown]
# **Character Level Tokenization**

# %%
text = "Hello World!"
chat_tokens = list(text)

# %%
chat_tokens
# Out:
# ['H', 'e', 'l', 'l', 'o', ' ', 'W', 'o', 'r', 'l', 'd', '!']

# %% [markdown]
# ##**Stemming**
# Stemming is the process of reducing a word to its Root Form. It chops off the ending of words using simple rule

# %%
from nltk.stem import PorterStemmer, SnowballStemmer, LancasterStemmer

# %%
words = [
    'running','runner','ran',
    'easily','fairly', 'fairness',
    'studies','studying','studied',
    'happiness', 'happily','happy',
    'connected', 'connection', 'connecting'
]

# %%
porter = PorterStemmer()
for word in words:
  print(f'{word}: {porter.stem(word)}')
# Out:
# running: run
# runner: runner
# ran: ran
# easily: easili
# fairly: fairli
# fairness: fair
# studies: studi
# studying: studi
# studied: studi
# happiness: happi
# happily: happili
# happy: happi
# connected: connect
# connection: connect
# connecting: connect

# %%
snowball = SnowballStemmer('english') # We need to specify language
for word in words:
  print(f'{word}: {snowball.stem(word)}')
# Out:
# running: run
# runner: runner
# ran: ran
# easily: easili
# fairly: fair
# fairness: fair
# studies: studi
# studying: studi
# studied: studi
# happiness: happi
# happily: happili
# happy: happi
# connected: connect
# connection: connect
# connecting: connect

# %%
lancaster = LancasterStemmer() # No need to pass language
for word in words:
  print(f'{word}: {lancaster.stem(word)}')
# Out:
# running: run
# runner: run
# ran: ran
# easily: easy
# fairly: fair
# fairness: fair
# studies: study
# studying: study
# studied: study
# happiness: happy
# happily: happy
# happy: happy
# connected: connect
# connection: connect
# connecting: connect

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Summary of Day 1:**
#
# `tokenization -> break text into smaller chunks
# stemming -> separate root words and suffixes
# lemmatization -> classify words into noun/verb.. grammar work`
