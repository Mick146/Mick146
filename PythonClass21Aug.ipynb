# %% [markdown]
# <a href="https://colab.research.google.com/github/Mick146/Mick146/blob/main/PythonClass21Aug.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Indexing Concept - It start from 0 and negative indexing start from -1

# %%
list1 = ['a','b','c','D', 5, 6, True, False]
print(list1)
print(type(list1))
# Out:
# ['a', 'b', 'c', 'D', 5, 6, True, False]
# <class 'list'>

# %%
print(list1[3])
# Out:
# D

# %% [markdown]
# Slicing

# %%
print(list1[ : ])
# Out:
# ['a', 'b', 'c', 'D', 5, 6, True, False]

# %%
print(list1[ : 0])
# Out:
# []
